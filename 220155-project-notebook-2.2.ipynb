# %%
#check gpu
import tensorflow as tf
print(tf.__version__)
print(tf.test.is_gpu_available())
# Out:
# 2.8.0
# WARNING:tensorflow:From C:\Users\nhata\AppData\Local\Temp\ipykernel_27372\2953355434.py:4: is_gpu_available (from tensorflow.python.framework.test_util) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.config.list_physical_devices('GPU')` instead.
# True

# %%
# Import libraries
import os
import pandas as pd
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv1D, MaxPooling1D, Flatten, Dense, Dropout
from tqdm import tqdm
import matplotlib.pyplot as plt 

# 1. Load and Preprocess Data
csv_path = 'data-vn-20230228\stock-historical-data'

keywords = [
    "ABB", "ACB", "BID", "CTG", "EIB", "BVB", "HDB", "KLB", "LPB", "MBB", "MSB",
    "NAB", "BAB", "NVB", "OCB", "PGB", "SSB", "SGB", "SHB", "STB", "TCB", "TPB",
    "VAB", "VCB", "VIB", "VPB", "VBB"
]

# Load data
df_list = []
for file in os.listdir(csv_path):
    if any(keyword in file for keyword in keywords) and file.endswith('.csv'):
        file_path = os.path.join(csv_path, file)
        data = pd.read_csv(file_path, on_bad_lines='skip').dropna()
        data['TradingDate'] = pd.to_datetime(data['TradingDate'], dayfirst=True, errors='coerce')
        df_list.append(data)

# Drop rows with missing values due to rolling calculations
df_list = [df.dropna().reset_index(drop=True) for df in df_list]

# Split into Train, Validation, and Test Sets
split_date_train = pd.Timestamp('2020-01-01')
split_date_val = pd.Timestamp('2021-01-01')
split_date_buffer = pd.Timestamp('2021-02-01')  # Buffer period

df_train_list, df_val_list, df_test_list = [], [], []
for df in df_list:
    train = df.loc[df['TradingDate'] < split_date_train]
    temp_test = df.loc[df['TradingDate'] >= split_date_train]
    val = temp_test.loc[temp_test['TradingDate'] < split_date_val]
    test = temp_test.loc[temp_test['TradingDate'] >= split_date_buffer]
    df_train_list.append(train)
    df_val_list.append(val)
    df_test_list.append(test)
# Out:
# C:\Users\nhata\AppData\Local\Temp\ipykernel_27372\2686427793.py:25: UserWarning: Parsing dates in %Y-%m-%d format when dayfirst=True was specified. Pass `dayfirst=False` or specify a format to silence this warning.
#   data['TradingDate'] = pd.to_datetime(data['TradingDate'], dayfirst=True, errors='coerce')
# C:\Users\nhata\AppData\Local\Temp\ipykernel_27372\2686427793.py:25: UserWarning: Parsing dates in %Y-%m-%d format when dayfirst=True was specified. Pass `dayfirst=False` or specify a format to silence this warning.
#   data['TradingDate'] = pd.to_datetime(data['TradingDate'], dayfirst=True, errors='coerce')
# C:\Users\nhata\AppData\Local\Temp\ipykernel_27372\2686427793.py:25: UserWarning: Parsing dates in %Y-%m-%d format when dayfirst=True was specified. Pass `dayfirst=False` or specify a format to silence this warning.
#   data['TradingDate'] = pd.to_datetime(data['TradingDate'], dayfirst=True, errors='coerce')
# C:\Users\nhata\AppData\Local\Temp\ipykernel_27372\2686427793.py:25: UserWarning: Parsing dates in %Y-%m-%d format when dayfirst=True was specified. Pass `dayfirst=False` or specify a format to silence this warning.
#   data['TradingDate'] = pd.to_datetime(data['TradingDate'], dayfirst=True, errors='coerce')
# C:\Users\nhata\AppData\Local\Temp\ipykernel_27372\2686427793.py:25: UserWarning: Parsing dates in %Y-%m-%d format when dayfirst=True was specified. Pass `dayfirst=False` or specify a format to silence this warning.
#   data['TradingDate'] = pd.to_datetime(data['TradingDate'], dayfirst=True, errors='coerce')
# C:\Users\nhata\AppData\Local\Temp\ipykernel_27372\2686427793.py:25: UserWarning: Parsing dates in %Y-%m-%d format when dayfirst=True was specified. Pass `dayfirst=False` or specify a format to silence this warning.
#   data['TradingDate'] = pd.to_datetime(data['TradingDate'], dayfirst=True, errors='coerce')
# C:\Users\nhata\AppData\Local\Temp\ipykernel_27372\2686427793.py:25: UserWarning: Parsing dates in %Y-%m-%d format when dayfirst=True was specified. Pass `dayfirst=False` or specify a format to silence this warning.
#   data['TradingDate'] = pd.to_datetime(data['TradingDate'], dayfirst=True, errors='coerce')
# C:\Users\nhata\AppData\Local\Temp\ipykernel_27372\2686427793.py:25: UserWarning: Parsing dates in %Y-%m-%d format when dayfirst=True was specified. Pass `dayfirst=False` or specify a format to silence this warning.
#   data['TradingDate'] = pd.to_datetime(data['TradingDate'], dayfirst=True, errors='coerce')
# C:\Users\nhata\AppData\Local\Temp\ipykernel_27372\2686427793.py:25: UserWarning: Parsing dates in %Y-%m-%d format when dayfirst=True was specified. Pass `dayfirst=False` or specify a format to silence this warning.
#   data['TradingDate'] = pd.to_datetime(data['TradingDate'], dayfirst=True, errors='coerce')
# C:\Users\nhata\AppData\Local\Temp\ipykernel_27372\2686427793.py:25: UserWarning: Parsing dates in %Y-%m-%d format when dayfirst=True was specified. Pass `dayfirst=False` or specify a format to silence this warning.
#   data['TradingDate'] = pd.to_datetime(data['TradingDate'], dayfirst=True, errors='coerce')
# C:\Users\nhata\AppData\Local\Temp\ipykernel_27372\2686427793.py:25: UserWarning: Parsing dates in %Y-%m-%d format when dayfirst=True was specified. Pass `dayfirst=False` or specify a format to silence this warning.
#   data['TradingDate'] = pd.to_datetime(data['TradingDate'], dayfirst=True, errors='coerce')
# C:\Users\nhata\AppData\Local\Temp\ipykernel_27372\2686427793.py:25: UserWarning: Parsing dates in %Y-%m-%d format when dayfirst=True was specified. Pass `dayfirst=False` or specify a format to silence this warning.
#   data['TradingDate'] = pd.to_datetime(data['TradingDate'], dayfirst=True, errors='coerce')
# C:\Users\nhata\AppData\Local\Temp\ipykernel_27372\2686427793.py:25: UserWarning: Parsing dates in %Y-%m-%d format when dayfirst=True was specified. Pass `dayfirst=False` or specify a format to silence this warning.
#   data['TradingDate'] = pd.to_datetime(data['TradingDate'], dayfirst=True, errors='coerce')
# C:\Users\nhata\AppData\Local\Temp\ipykernel_27372\2686427793.py:25: UserWarning: Parsing dates in %Y-%m-%d format when dayfirst=True was specified. Pass `dayfirst=False` or specify a format to silence this warning.
#   data['TradingDate'] = pd.to_datetime(data['TradingDate'], dayfirst=True, errors='coerce')
# C:\Users\nhata\AppData\Local\Temp\ipykernel_27372\2686427793.py:25: UserWarning: Parsing dates in %Y-%m-%d format when dayfirst=True was specified. Pass `dayfirst=False` or specify a format to silence this warning.
#   data['TradingDate'] = pd.to_datetime(data['TradingDate'], dayfirst=True, errors='coerce')
# C:\Users\nhata\AppData\Local\Temp\ipykernel_27372\2686427793.py:25: UserWarning: Parsing dates in %Y-%m-%d format when dayfirst=True was specified. Pass `dayfirst=False` or specify a format to silence this warning.
#   data['TradingDate'] = pd.to_datetime(data['TradingDate'], dayfirst=True, errors='coerce')
# C:\Users\nhata\AppData\Local\Temp\ipykernel_27372\2686427793.py:25: UserWarning: Parsing dates in %Y-%m-%d format when dayfirst=True was specified. Pass `dayfirst=False` or specify a format to silence this warning.
#   data['TradingDate'] = pd.to_datetime(data['TradingDate'], dayfirst=True, errors='coerce')
# C:\Users\nhata\AppData\Local\Temp\ipykernel_27372\2686427793.py:25: UserWarning: Parsing dates in %Y-%m-%d format when dayfirst=True was specified. Pass `dayfirst=False` or specify a format to silence this warning.
#   data['TradingDate'] = pd.to_datetime(data['TradingDate'], dayfirst=True, errors='coerce')
# C:\Users\nhata\AppData\Local\Temp\ipykernel_27372\2686427793.py:25: UserWarning: Parsing dates in %Y-%m-%d format when dayfirst=True was specified. Pass `dayfirst=False` or specify a format to silence this warning.
#   data['TradingDate'] = pd.to_datetime(data['TradingDate'], dayfirst=True, errors='coerce')

# %%
# Function to normalize data with Min-Max scaling
def min_max_normalize(X_data, y_data=None):
    print("Normalizing data with Min-Max scaling...")
    X_norm = X_data.copy()
    y_norm = y_data.copy() if y_data is not None else None

    for i in range(len(X_data)):
        for j in range(X_data.shape[2]):
            min_feature = np.min(X_data[i][:, j])
            max_feature = np.max(X_data[i][:, j])
            X_norm[i][:, j] = (X_data[i][:, j] - min_feature) / (max_feature - min_feature) if max_feature > min_feature else 0
        if (i+1) % 100 == 0 or i == len(X_data) - 1:  # Print progress every 100 samples
            print(f"Processed normalization for sample {i+1}/{len(X_data)}")

    if y_data is not None:
        for i in range(len(y_data)):
            min_label = np.min(X_data[i][:, 1])
            max_label = np.max(X_data[i][:, 1])
            y_norm[i] = (y_data[i] - min_label) / (max_label - min_label) if max_label > min_label else 0

    print("Normalization complete.")
    return X_norm, y_norm

# %%
import numpy as np
from tqdm import tqdm

# Function to split a dataset into time windows for k-day ahead prediction
def create_time_window_samples_k_day(df_list, window_size=30, k=3):
    X_data_k_day = []
    y_data_k_day = []

    # Wrap tqdm around the main loop to track progress
    for df in tqdm(df_list, desc="Processing DataFrames"):
        for i in range(0, len(df) - window_size - k):
            current_feature = df.iloc[i:i + window_size, 1:6].values
            data_label = df.iloc[i + window_size + k - 1, 1]  # Only the k-th day 'Open' price
            X_data_k_day.append(current_feature)
            y_data_k_day.append(data_label)

    return np.array(X_data_k_day), np.array(y_data_k_day)

# Define the window size and k-day ahead forecast
window_size = 30
k = 3  # 3 days ahead forecast

# Generate training, validation, and test samples for k-day forecast
X_train_k_day, y_train_k_day = create_time_window_samples_k_day(df_train_list, window_size, k)
X_val_k_day, y_val_k_day = create_time_window_samples_k_day(df_val_list, window_size, k)
X_test_k_day, y_test_k_day = create_time_window_samples_k_day(df_test_list, window_size, k)

# Normalize the data as before
X_train_k_day_norm, y_train_k_day_norm = min_max_normalize(X_train_k_day, y_train_k_day)
X_val_k_day_norm, y_val_k_day_norm = min_max_normalize(X_val_k_day, y_val_k_day)
X_test_k_day_norm, y_test_k_day_norm = min_max_normalize(X_test_k_day, y_test_k_day)
# Out:
# Processing DataFrames: 100%|██████████| 27/27 [00:02<00:00, 12.21it/s]
# Processing DataFrames: 100%|██████████| 27/27 [00:00<00:00, 98.60it/s]
# Processing DataFrames: 100%|██████████| 27/27 [00:00<00:00, 28.03it/s]
# Normalizing data with Min-Max scaling...
# Processed normalization for sample 100/22147
# Processed normalization for sample 200/22147
# Processed normalization for sample 300/22147
# Processed normalization for sample 400/22147
# Processed normalization for sample 500/22147
# Processed normalization for sample 600/22147
# Processed normalization for sample 700/22147
# Processed normalization for sample 800/22147
# Processed normalization for sample 900/22147
# Processed normalization for sample 1000/22147
# Processed normalization for sample 1100/22147
# Processed normalization for sample 1200/22147
# Processed normalization for sample 1300/22147
# Processed normalization for sample 1400/22147
# Processed normalization for sample 1500/22147
# Processed normalization for sample 1600/22147
# Processed normalization for sample 1700/22147
# Processed normalization for sample 1800/22147
# Processed normalization for sample 1900/22147
# Processed normalization for sample 2000/22147
# Processed normalization for sample 2100/22147
# Processed normalization for sample 2200/22147
# Processed normalization for sample 2300/22147
# Processed normalization for sample 2400/22147
# Processed normalization for sample 2500/22147
# Processed normalization for sample 2600/22147
# Processed normalization for sample 2700/22147
# Processed normalization for sample 2800/22147
# Processed normalization for sample 2900/22147
# Processed normalization for sample 3000/22147
# Processed normalization for sample 3100/22147
# Processed normalization for sample 3200/22147
# Processed normalization for sample 3300/22147
# Processed normalization for sample 3400/22147
# Processed normalization for sample 3500/22147
# Processed normalization for sample 3600/22147
# Processed normalization for sample 3700/22147
# Processed normalization for sample 3800/22147
# Processed normalization for sample 3900/22147
# Processed normalization for sample 4000/22147
# Processed normalization for sample 4100/22147
# Processed normalization for sample 4200/22147
# Processed normalization for sample 4300/22147
# Processed normalization for sample 4400/22147
# Processed normalization for sample 4500/22147
# Processed normalization for sample 4600/22147
# Processed normalization for sample 4700/22147
# Processed normalization for sample 4800/22147
# Processed normalization for sample 4900/22147
# Processed normalization for sample 5000/22147
# Processed normalization for sample 5100/22147
# Processed normalization for sample 5200/22147
# Processed normalization for sample 5300/22147
# Processed normalization for sample 5400/22147
# Processed normalization for sample 5500/22147
# Processed normalization for sample 5600/22147
# Processed normalization for sample 5700/22147
# Processed normalization for sample 5800/22147
# Processed normalization for sample 5900/22147
# Processed normalization for sample 6000/22147
# Processed normalization for sample 6100/22147
# Processed normalization for sample 6200/22147
# Processed normalization for sample 6300/22147
# Processed normalization for sample 6400/22147
# Processed normalization for sample 6500/22147
# Processed normalization for sample 6600/22147
# Processed normalization for sample 6700/22147
# Processed normalization for sample 6800/22147
# Processed normalization for sample 6900/22147
# Processed normalization for sample 7000/22147
# Processed normalization for sample 7100/22147
# Processed normalization for sample 7200/22147
# Processed normalization for sample 7300/22147
# Processed normalization for sample 7400/22147
# Processed normalization for sample 7500/22147
# Processed normalization for sample 7600/22147
# Processed normalization for sample 7700/22147
# Processed normalization for sample 7800/22147
# Processed normalization for sample 7900/22147
# Processed normalization for sample 8000/22147
# Processed normalization for sample 8100/22147
# Processed normalization for sample 8200/22147
# Processed normalization for sample 8300/22147
# Processed normalization for sample 8400/22147
# Processed normalization for sample 8500/22147
# Processed normalization for sample 8600/22147
# Processed normalization for sample 8700/22147
# Processed normalization for sample 8800/22147
# Processed normalization for sample 8900/22147
# Processed normalization for sample 9000/22147
# Processed normalization for sample 9100/22147
# Processed normalization for sample 9200/22147
# Processed normalization for sample 9300/22147
# Processed normalization for sample 9400/22147
# Processed normalization for sample 9500/22147
# Processed normalization for sample 9600/22147
# Processed normalization for sample 9700/22147
# Processed normalization for sample 9800/22147
# Processed normalization for sample 9900/22147
# Processed normalization for sample 10000/22147
# Processed normalization for sample 10100/22147
# Processed normalization for sample 10200/22147
# Processed normalization for sample 10300/22147
# Processed normalization for sample 10400/22147
# Processed normalization for sample 10500/22147
# Processed normalization for sample 10600/22147
# Processed normalization for sample 10700/22147
# Processed normalization for sample 10800/22147
# Processed normalization for sample 10900/22147
# Processed normalization for sample 11000/22147
# Processed normalization for sample 11100/22147
# Processed normalization for sample 11200/22147
# Processed normalization for sample 11300/22147
# Processed normalization for sample 11400/22147
# Processed normalization for sample 11500/22147
# Processed normalization for sample 11600/22147
# Processed normalization for sample 11700/22147
# Processed normalization for sample 11800/22147
# Processed normalization for sample 11900/22147
# Processed normalization for sample 12000/22147
# Processed normalization for sample 12100/22147
# Processed normalization for sample 12200/22147
# Processed normalization for sample 12300/22147
# Processed normalization for sample 12400/22147
# Processed normalization for sample 12500/22147
# Processed normalization for sample 12600/22147
# Processed normalization for sample 12700/22147
# Processed normalization for sample 12800/22147
# Processed normalization for sample 12900/22147
# Processed normalization for sample 13000/22147
# Processed normalization for sample 13100/22147
# Processed normalization for sample 13200/22147
# Processed normalization for sample 13300/22147
# Processed normalization for sample 13400/22147
# Processed normalization for sample 13500/22147
# Processed normalization for sample 13600/22147
# Processed normalization for sample 13700/22147
# Processed normalization for sample 13800/22147
# Processed normalization for sample 13900/22147
# Processed normalization for sample 14000/22147
# Processed normalization for sample 14100/22147
# Processed normalization for sample 14200/22147
# Processed normalization for sample 14300/22147
# Processed normalization for sample 14400/22147
# Processed normalization for sample 14500/22147
# Processed normalization for sample 14600/22147
# Processed normalization for sample 14700/22147
# Processed normalization for sample 14800/22147
# Processed normalization for sample 14900/22147
# Processed normalization for sample 15000/22147
# Processed normalization for sample 15100/22147
# Processed normalization for sample 15200/22147
# Processed normalization for sample 15300/22147
# Processed normalization for sample 15400/22147
# Processed normalization for sample 15500/22147
# Processed normalization for sample 15600/22147
# Processed normalization for sample 15700/22147
# Processed normalization for sample 15800/22147
# Processed normalization for sample 15900/22147
# Processed normalization for sample 16000/22147
# Processed normalization for sample 16100/22147
# Processed normalization for sample 16200/22147
# Processed normalization for sample 16300/22147
# Processed normalization for sample 16400/22147
# Processed normalization for sample 16500/22147
# Processed normalization for sample 16600/22147
# Processed normalization for sample 16700/22147
# Processed normalization for sample 16800/22147
# Processed normalization for sample 16900/22147
# Processed normalization for sample 17000/22147
# Processed normalization for sample 17100/22147
# Processed normalization for sample 17200/22147
# Processed normalization for sample 17300/22147
# Processed normalization for sample 17400/22147
# Processed normalization for sample 17500/22147
# Processed normalization for sample 17600/22147
# Processed normalization for sample 17700/22147
# Processed normalization for sample 17800/22147
# Processed normalization for sample 17900/22147
# Processed normalization for sample 18000/22147
# Processed normalization for sample 18100/22147
# Processed normalization for sample 18200/22147
# Processed normalization for sample 18300/22147
# Processed normalization for sample 18400/22147
# Processed normalization for sample 18500/22147
# Processed normalization for sample 18600/22147
# Processed normalization for sample 18700/22147
# Processed normalization for sample 18800/22147
# Processed normalization for sample 18900/22147
# Processed normalization for sample 19000/22147
# Processed normalization for sample 19100/22147
# Processed normalization for sample 19200/22147
# Processed normalization for sample 19300/22147
# Processed normalization for sample 19400/22147
# Processed normalization for sample 19500/22147
# Processed normalization for sample 19600/22147
# Processed normalization for sample 19700/22147
# Processed normalization for sample 19800/22147
# Processed normalization for sample 19900/22147
# Processed normalization for sample 20000/22147
# Processed normalization for sample 20100/22147
# Processed normalization for sample 20200/22147
# Processed normalization for sample 20300/22147
# Processed normalization for sample 20400/22147
# Processed normalization for sample 20500/22147
# Processed normalization for sample 20600/22147
# Processed normalization for sample 20700/22147
# Processed normalization for sample 20800/22147
# Processed normalization for sample 20900/22147
# Processed normalization for sample 21000/22147
# Processed normalization for sample 21100/22147
# Processed normalization for sample 21200/22147
# Processed normalization for sample 21300/22147
# Processed normalization for sample 21400/22147
# Processed normalization for sample 21500/22147
# Processed normalization for sample 21600/22147
# Processed normalization for sample 21700/22147
# Processed normalization for sample 21800/22147
# Processed normalization for sample 21900/22147
# Processed normalization for sample 22000/22147
# Processed normalization for sample 22100/22147
# Processed normalization for sample 22147/22147
# Normalization complete.
# Normalizing data with Min-Max scaling...
# Processed normalization for sample 100/3036
# Processed normalization for sample 200/3036
# Processed normalization for sample 300/3036
# Processed normalization for sample 400/3036
# Processed normalization for sample 500/3036
# Processed normalization for sample 600/3036
# Processed normalization for sample 700/3036
# Processed normalization for sample 800/3036
# Processed normalization for sample 900/3036
# Processed normalization for sample 1000/3036
# Processed normalization for sample 1100/3036
# Processed normalization for sample 1200/3036
# Processed normalization for sample 1300/3036
# Processed normalization for sample 1400/3036
# Processed normalization for sample 1500/3036
# Processed normalization for sample 1600/3036
# Processed normalization for sample 1700/3036
# Processed normalization for sample 1800/3036
# Processed normalization for sample 1900/3036
# Processed normalization for sample 2000/3036
# Processed normalization for sample 2100/3036
# Processed normalization for sample 2200/3036
# Processed normalization for sample 2300/3036
# Processed normalization for sample 2400/3036
# Processed normalization for sample 2500/3036
# Processed normalization for sample 2600/3036
# Processed normalization for sample 2700/3036
# Processed normalization for sample 2800/3036
# Processed normalization for sample 2900/3036
# Processed normalization for sample 3000/3036
# Processed normalization for sample 3036/3036
# Normalization complete.
# Normalizing data with Min-Max scaling...
# Processed normalization for sample 100/10310
# Processed normalization for sample 200/10310
# Processed normalization for sample 300/10310
# Processed normalization for sample 400/10310
# Processed normalization for sample 500/10310
# Processed normalization for sample 600/10310
# Processed normalization for sample 700/10310
# Processed normalization for sample 800/10310
# Processed normalization for sample 900/10310
# Processed normalization for sample 1000/10310
# Processed normalization for sample 1100/10310
# Processed normalization for sample 1200/10310
# Processed normalization for sample 1300/10310
# Processed normalization for sample 1400/10310
# Processed normalization for sample 1500/10310
# Processed normalization for sample 1600/10310
# Processed normalization for sample 1700/10310
# Processed normalization for sample 1800/10310
# Processed normalization for sample 1900/10310
# Processed normalization for sample 2000/10310
# Processed normalization for sample 2100/10310
# Processed normalization for sample 2200/10310
# Processed normalization for sample 2300/10310
# Processed normalization for sample 2400/10310
# Processed normalization for sample 2500/10310
# Processed normalization for sample 2600/10310
# Processed normalization for sample 2700/10310
# Processed normalization for sample 2800/10310
# Processed normalization for sample 2900/10310
# Processed normalization for sample 3000/10310
# Processed normalization for sample 3100/10310
# Processed normalization for sample 3200/10310
# Processed normalization for sample 3300/10310
# Processed normalization for sample 3400/10310
# Processed normalization for sample 3500/10310
# Processed normalization for sample 3600/10310
# Processed normalization for sample 3700/10310
# Processed normalization for sample 3800/10310
# Processed normalization for sample 3900/10310
# Processed normalization for sample 4000/10310
# Processed normalization for sample 4100/10310
# Processed normalization for sample 4200/10310
# Processed normalization for sample 4300/10310
# Processed normalization for sample 4400/10310
# Processed normalization for sample 4500/10310
# Processed normalization for sample 4600/10310
# Processed normalization for sample 4700/10310
# Processed normalization for sample 4800/10310
# Processed normalization for sample 4900/10310
# Processed normalization for sample 5000/10310
# Processed normalization for sample 5100/10310
# Processed normalization for sample 5200/10310
# Processed normalization for sample 5300/10310
# Processed normalization for sample 5400/10310
# Processed normalization for sample 5500/10310
# Processed normalization for sample 5600/10310
# Processed normalization for sample 5700/10310
# Processed normalization for sample 5800/10310
# Processed normalization for sample 5900/10310
# Processed normalization for sample 6000/10310
# Processed normalization for sample 6100/10310
# Processed normalization for sample 6200/10310
# Processed normalization for sample 6300/10310
# Processed normalization for sample 6400/10310
# Processed normalization for sample 6500/10310
# Processed normalization for sample 6600/10310
# Processed normalization for sample 6700/10310
# Processed normalization for sample 6800/10310
# Processed normalization for sample 6900/10310
# Processed normalization for sample 7000/10310
# Processed normalization for sample 7100/10310
# Processed normalization for sample 7200/10310
# Processed normalization for sample 7300/10310
# Processed normalization for sample 7400/10310
# Processed normalization for sample 7500/10310
# Processed normalization for sample 7600/10310
# Processed normalization for sample 7700/10310
# Processed normalization for sample 7800/10310
# Processed normalization for sample 7900/10310
# Processed normalization for sample 8000/10310
# Processed normalization for sample 8100/10310
# Processed normalization for sample 8200/10310
# Processed normalization for sample 8300/10310
# Processed normalization for sample 8400/10310
# Processed normalization for sample 8500/10310
# Processed normalization for sample 8600/10310
# Processed normalization for sample 8700/10310
# Processed normalization for sample 8800/10310
# Processed normalization for sample 8900/10310
# Processed normalization for sample 9000/10310
# Processed normalization for sample 9100/10310
# Processed normalization for sample 9200/10310
# Processed normalization for sample 9300/10310
# Processed normalization for sample 9400/10310
# Processed normalization for sample 9500/10310
# Processed normalization for sample 9600/10310
# Processed normalization for sample 9700/10310
# Processed normalization for sample 9800/10310
# Processed normalization for sample 9900/10310
# Processed normalization for sample 10000/10310
# Processed normalization for sample 10100/10310
# Processed normalization for sample 10200/10310
# Processed normalization for sample 10300/10310
# Processed normalization for sample 10310/10310
# Normalization complete.

# %%
# Import libraries
import tensorflow as tf
from tensorflow.keras.layers import Conv1D, MaxPooling1D, Flatten, Dense, BatchNormalization, Dropout, AveragePooling1D

# Build the model architecture
model = tf.keras.Sequential()
model.add(Conv1D(32, kernel_size=3, activation='relu', input_shape=(window_size, 5), padding='same'))
model.add(MaxPooling1D(pool_size=2))
model.add(Conv1D(32, kernel_size=3, activation='relu', padding='same'))
model.add(MaxPooling1D(2))
model.add(Conv1D(32, kernel_size=3, activation='relu', padding='same'))
model.add(MaxPooling1D(2))
model.add(Conv1D(32, kernel_size=3, activation='relu', padding='same'))
model.add(MaxPooling1D(2))
model.add(Flatten())
model.add(Dense(100, activation='relu'))
model.add(Dense(1)) # By default: activation='linear', i.e., passing through f(x) = x

# %%
# Compile and train the model with Mean Squared Error loss function
model.summary()
model.compile(optimizer= tf.keras.optimizers.Adam(learning_rate=0.01), loss='mse', metrics=['mse'])
history = model.fit(X_train_k_day_norm, y_train_k_day_norm, validation_data=(X_val_k_day_norm,y_val_k_day_norm), epochs=20, batch_size=2048, verbose=1)
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d (Conv1D)              (None, 30, 32)            512
# _________________________________________________________________
# max_pooling1d (MaxPooling1D) (None, 15, 32)            0
# _________________________________________________________________
# conv1d_1 (Conv1D)            (None, 15, 32)            3104
# _________________________________________________________________
# max_pooling1d_1 (MaxPooling1 (None, 7, 32)             0
# _________________________________________________________________
# conv1d_2 (Conv1D)            (None, 7, 32)             3104
# _________________________________________________________________
# max_pooling1d_2 (MaxPooling1 (None, 3, 32)             0
# _________________________________________________________________
# conv1d_3 (Conv1D)            (None, 3, 32)             3104
# _________________________________________________________________
# max_pooling1d_3 (MaxPooling1 (None, 1, 32)             0
# _________________________________________________________________
# flatten (Flatten)            (None, 32)                0
# _________________________________________________________________
# dense (Dense)                (None, 100)               3300
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 101
# =================================================================
# Total params: 13,225
# Trainable params: 13,225
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/20
# 11/11 [==============================] - 4s 40ms/step - loss: 0.3207 - mse: 0.3207 - val_loss: 0.3961 - val_mse: 0.3961
# Epoch 2/20
# 11/11 [==============================] - 0s 9ms/step - loss: 0.2382 - mse: 0.2382 - val_loss: 0.3232 - val_mse: 0.3232
# Epoch 3/20
# 11/11 [==============================] - 0s 9ms/step - loss: 0.2014 - mse: 0.2014 - val_loss: 0.2875 - val_mse: 0.2875
# Epoch 4/20
# 11/11 [==============================] - 0s 9ms/step - loss: 0.1816 - mse: 0.1816 - val_loss: 0.2761 - val_mse: 0.2761
# Epoch 5/20
# 11/11 [==============================] - 0s 9ms/step - loss: 0.1615 - mse: 0.1615 - val_loss: 0.2403 - val_mse: 0.2403
# Epoch 6/20
# 11/11 [==============================] - 0s 8ms/step - loss: 0.1461 - mse: 0.1461 - val_loss: 0.2272 - val_mse: 0.2272
# Epoch 7/20
# 11/11 [==============================] - 0s 9ms/step - loss: 0.1416 - mse: 0.1416 - val_loss: 0.2303 - val_mse: 0.2303
# Epoch 8/20
# 11/11 [==============================] - 0s 9ms/step - loss: 0.1393 - mse: 0.1393 - val_loss: 0.2207 - val_mse: 0.2207
# Epoch 9/20
# 11/11 [==============================] - 0s 8ms/step - loss: 0.1375 - mse: 0.1375 - val_loss: 0.2236 - val_mse: 0.2236
# Epoch 10/20
# 11/11 [==============================] - 0s 9ms/step - loss: 0.1361 - mse: 0.1361 - val_loss: 0.2190 - val_mse: 0.2190
# Epoch 11/20
# 11/11 [==============================] - 0s 8ms/step - loss: 0.1345 - mse: 0.1345 - val_loss: 0.2234 - val_mse: 0.2234
# Epoch 12/20
# 11/11 [==============================] - 0s 8ms/step - loss: 0.1327 - mse: 0.1327 - val_loss: 0.2198 - val_mse: 0.2198
# Epoch 13/20
# 11/11 [==============================] - 0s 8ms/step - loss: 0.1332 - mse: 0.1332 - val_loss: 0.2195 - val_mse: 0.2195
# Epoch 14/20
# 11/11 [==============================] - 0s 9ms/step - loss: 0.1317 - mse: 0.1317 - val_loss: 0.2199 - val_mse: 0.2199
# Epoch 15/20
# 11/11 [==============================] - 0s 9ms/step - loss: 0.1310 - mse: 0.1310 - val_loss: 0.2206 - val_mse: 0.2206
# Epoch 16/20
# 11/11 [==============================] - 0s 8ms/step - loss: 0.1284 - mse: 0.1284 - val_loss: 0.2200 - val_mse: 0.2200
# Epoch 17/20
# 11/11 [==============================] - 0s 8ms/step - loss: 0.1289 - mse: 0.1289 - val_loss: 0.2318 - val_mse: 0.2318
# Epoch 18/20
# 11/11 [==============================] - 0s 8ms/step - loss: 0.1270 - mse: 0.1270 - val_loss: 0.2250 - val_mse: 0.2250
# Epoch 19/20
# 11/11 [==============================] - 0s 8ms/step - loss: 0.1245 - mse: 0.1245 - val_loss: 0.2252 - val_mse: 0.2252
# Epoch 20/20
# 11/11 [==============================] - 0s 9ms/step - loss: 0.1203 - mse: 0.1203 - val_loss: 0.2243 - val_mse: 0.2243

# %%
from tensorflow.keras.layers import LSTM, Flatten, Dense

# Build the LSTM model architecture
modelLSTM = tf.keras.Sequential()
modelLSTM.add(LSTM(50, return_sequences=True, input_shape=(window_size, 5)))  # First LSTM layer with 50 units
modelLSTM.add(Dropout(0.2))  # Dropout layer for regularization
modelLSTM.add(LSTM(50, return_sequences=False))  # Second LSTM layer with 50 units
modelLSTM.add(Dropout(0.2))  # Another Dropout layer for regularization
modelLSTM.add(Dense(100, activation='relu'))  # Dense layer with 100 units and ReLU activation
modelLSTM.add(Dense(1))  # Output layer for regression (predicting stock prices)

# %%
# Compile the model
modelLSTM.summary()
modelLSTM.compile(optimizer= tf.keras.optimizers.Adam(learning_rate=0.01), loss='mse', metrics=['mse'])
history = modelLSTM.fit(X_train_k_day_norm, y_train_k_day_norm, validation_data=(X_val_k_day_norm,y_val_k_day_norm), epochs=20, batch_size=2048, verbose=1)
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm (LSTM)                  (None, 30, 50)            11200
# _________________________________________________________________
# dropout (Dropout)            (None, 30, 50)            0
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 50)                20200
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 50)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 100)               5100
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 101
# =================================================================
# Total params: 36,601
# Trainable params: 36,601
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/20
# 11/11 [==============================] - 3s 71ms/step - loss: 0.2709 - mse: 0.2709 - val_loss: 0.2654 - val_mse: 0.2654
# Epoch 2/20
# 11/11 [==============================] - 0s 16ms/step - loss: 0.1734 - mse: 0.1734 - val_loss: 0.2509 - val_mse: 0.2509
# Epoch 3/20
# 11/11 [==============================] - 0s 15ms/step - loss: 0.1552 - mse: 0.1552 - val_loss: 0.2339 - val_mse: 0.2339
# Epoch 4/20
# 11/11 [==============================] - 0s 14ms/step - loss: 0.1471 - mse: 0.1471 - val_loss: 0.2306 - val_mse: 0.2306
# Epoch 5/20
# 11/11 [==============================] - 0s 15ms/step - loss: 0.1442 - mse: 0.1442 - val_loss: 0.2224 - val_mse: 0.2224
# Epoch 6/20
# 11/11 [==============================] - 0s 15ms/step - loss: 0.1432 - mse: 0.1432 - val_loss: 0.2226 - val_mse: 0.2226
# Epoch 7/20
# 11/11 [==============================] - 0s 15ms/step - loss: 0.1425 - mse: 0.1425 - val_loss: 0.2204 - val_mse: 0.2204
# Epoch 8/20
# 11/11 [==============================] - 0s 15ms/step - loss: 0.1411 - mse: 0.1411 - val_loss: 0.2192 - val_mse: 0.2192
# Epoch 9/20
# 11/11 [==============================] - 0s 15ms/step - loss: 0.1406 - mse: 0.1406 - val_loss: 0.2191 - val_mse: 0.2191
# Epoch 10/20
# 11/11 [==============================] - 0s 14ms/step - loss: 0.1403 - mse: 0.1403 - val_loss: 0.2183 - val_mse: 0.2183
# Epoch 11/20
# 11/11 [==============================] - 0s 15ms/step - loss: 0.1392 - mse: 0.1392 - val_loss: 0.2183 - val_mse: 0.2183
# Epoch 12/20
# 11/11 [==============================] - 0s 15ms/step - loss: 0.1402 - mse: 0.1402 - val_loss: 0.2200 - val_mse: 0.2200
# Epoch 13/20
# 11/11 [==============================] - 0s 15ms/step - loss: 0.1386 - mse: 0.1386 - val_loss: 0.2179 - val_mse: 0.2179
# Epoch 14/20
# 11/11 [==============================] - 0s 15ms/step - loss: 0.1388 - mse: 0.1388 - val_loss: 0.2186 - val_mse: 0.2186
# Epoch 15/20
# 11/11 [==============================] - 0s 15ms/step - loss: 0.1374 - mse: 0.1374 - val_loss: 0.2199 - val_mse: 0.2199
# Epoch 16/20
# 11/11 [==============================] - 0s 15ms/step - loss: 0.1377 - mse: 0.1377 - val_loss: 0.2195 - val_mse: 0.2195
# Epoch 17/20
# 11/11 [==============================] - 0s 15ms/step - loss: 0.1381 - mse: 0.1381 - val_loss: 0.2185 - val_mse: 0.2185
# Epoch 18/20
# 11/11 [==============================] - 0s 15ms/step - loss: 0.1372 - mse: 0.1372 - val_loss: 0.2179 - val_mse: 0.2179
# Epoch 19/20
# 11/11 [==============================] - 0s 15ms/step - loss: 0.1377 - mse: 0.1377 - val_loss: 0.2173 - val_mse: 0.2173
# Epoch 20/20
# 11/11 [==============================] - 0s 15ms/step - loss: 0.1367 - mse: 0.1367 - val_loss: 0.2178 - val_mse: 0.2178

# %%
# Build the GRU model architecture
modelGRU = tf.keras.Sequential()
modelGRU.add(tf.keras.layers.GRU(64, return_sequences=True, input_shape=(window_size, 5)))  # First GRU layer with 64 units
modelGRU.add(tf.keras.layers.Dropout(0.2))  # Dropout layer for regularization
modelGRU.add(tf.keras.layers.GRU(64, return_sequences=False))  # Second GRU layer with 64 units
modelGRU.add(tf.keras.layers.Dropout(0.2))  # Another Dropout layer for regularization
modelGRU.add(tf.keras.layers.Dense(100, activation='relu'))  # Dense layer with 100 units and ReLU activation
modelGRU.add(tf.keras.layers.Dense(1))  # Output layer for regression (predicting stock prices)

# %%
# Compile the model
modelGRU.summary()
modelGRU.compile(optimizer= tf.keras.optimizers.Adam(learning_rate=0.01), loss='mse', metrics=['mse'])
history = modelGRU.fit(X_train_k_day_norm, y_train_k_day_norm, validation_data=(X_val_k_day_norm,y_val_k_day_norm), epochs=20, batch_size=2048, verbose=1)
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# gru (GRU)                    (None, 30, 64)            13632
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 30, 64)            0
# _________________________________________________________________
# gru_1 (GRU)                  (None, 64)                24960
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 64)                0
# _________________________________________________________________
# dense_4 (Dense)              (None, 100)               6500
# _________________________________________________________________
# dense_5 (Dense)              (None, 1)                 101
# =================================================================
# Total params: 45,193
# Trainable params: 45,193
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/20
# 11/11 [==============================] - 2s 55ms/step - loss: 0.2687 - mse: 0.2687 - val_loss: 0.2388 - val_mse: 0.2388
# Epoch 2/20
# 11/11 [==============================] - 0s 13ms/step - loss: 0.1612 - mse: 0.1612 - val_loss: 0.2368 - val_mse: 0.2368
# Epoch 3/20
# 11/11 [==============================] - 0s 13ms/step - loss: 0.1484 - mse: 0.1484 - val_loss: 0.2272 - val_mse: 0.2272
# Epoch 4/20
# 11/11 [==============================] - 0s 13ms/step - loss: 0.1431 - mse: 0.1431 - val_loss: 0.2193 - val_mse: 0.2193
# Epoch 5/20
# 11/11 [==============================] - 0s 13ms/step - loss: 0.1410 - mse: 0.1410 - val_loss: 0.2242 - val_mse: 0.2242
# Epoch 6/20
# 11/11 [==============================] - 0s 13ms/step - loss: 0.1404 - mse: 0.1404 - val_loss: 0.2189 - val_mse: 0.2189
# Epoch 7/20
# 11/11 [==============================] - 0s 13ms/step - loss: 0.1395 - mse: 0.1395 - val_loss: 0.2205 - val_mse: 0.2205
# Epoch 8/20
# 11/11 [==============================] - 0s 12ms/step - loss: 0.1389 - mse: 0.1389 - val_loss: 0.2221 - val_mse: 0.2221
# Epoch 9/20
# 11/11 [==============================] - 0s 13ms/step - loss: 0.1387 - mse: 0.1387 - val_loss: 0.2242 - val_mse: 0.2242
# Epoch 10/20
# 11/11 [==============================] - 0s 13ms/step - loss: 0.1380 - mse: 0.1380 - val_loss: 0.2220 - val_mse: 0.2220
# Epoch 11/20
# 11/11 [==============================] - 0s 12ms/step - loss: 0.1368 - mse: 0.1368 - val_loss: 0.2238 - val_mse: 0.2238
# Epoch 12/20
# 11/11 [==============================] - 0s 13ms/step - loss: 0.1368 - mse: 0.1368 - val_loss: 0.2187 - val_mse: 0.2187
# Epoch 13/20
# 11/11 [==============================] - 0s 13ms/step - loss: 0.1360 - mse: 0.1360 - val_loss: 0.2181 - val_mse: 0.2181
# Epoch 14/20
# 11/11 [==============================] - 0s 13ms/step - loss: 0.1367 - mse: 0.1367 - val_loss: 0.2170 - val_mse: 0.2170
# Epoch 15/20
# 11/11 [==============================] - 0s 12ms/step - loss: 0.1368 - mse: 0.1368 - val_loss: 0.2192 - val_mse: 0.2192
# Epoch 16/20
# 11/11 [==============================] - 0s 13ms/step - loss: 0.1353 - mse: 0.1353 - val_loss: 0.2189 - val_mse: 0.2189
# Epoch 17/20
# 11/11 [==============================] - 0s 13ms/step - loss: 0.1345 - mse: 0.1345 - val_loss: 0.2191 - val_mse: 0.2191
# Epoch 18/20
# 11/11 [==============================] - 0s 13ms/step - loss: 0.1352 - mse: 0.1352 - val_loss: 0.2196 - val_mse: 0.2196
# Epoch 19/20
# 11/11 [==============================] - 0s 12ms/step - loss: 0.1343 - mse: 0.1343 - val_loss: 0.2345 - val_mse: 0.2345
# Epoch 20/20
# 11/11 [==============================] - 0s 12ms/step - loss: 0.1343 - mse: 0.1343 - val_loss: 0.2202 - val_mse: 0.2202

# %%
loss_Conv1D, mse_Conv1D = model.evaluate(X_test_k_day_norm, y_test_k_day_norm, verbose=0)
loss_LSTM, mse_LSTM = modelLSTM.evaluate(X_test_k_day_norm, y_test_k_day_norm, verbose=0)
loss_GRU, mse_GRU = modelGRU.evaluate(X_test_k_day_norm, y_test_k_day_norm, verbose=0)

print(f'Conv1D Model - Test loss: {loss_Conv1D:.3f}, Test MSE: {mse_Conv1D:.3f}')
print(f'LSTM Model - Test loss: {loss_LSTM:.3f}, Test MSE: {mse_LSTM:.3f}')
print(f'GRU Model - Test loss: {loss_GRU:.3f}, Test MSE: {mse_GRU:.3f}')
# Out:
# Conv1D Model - Test loss: 0.091, Test MSE: 0.091
# LSTM Model - Test loss: 0.086, Test MSE: 0.086
# GRU Model - Test loss: 0.088, Test MSE: 0.088

# %%
yhat_Conv1D = model.predict(X_test_k_day_norm)
yhat_LSTM = modelLSTM.predict(X_test_k_day_norm)
yhat_GRU = modelGRU.predict(X_test_k_day_norm)

# %%
import matplotlib.pyplot as plt

# Plot the true and predicted stock prices for k-day forecast
plt.figure(figsize=(12, 6))
plt.plot(y_test_k_day_norm, label='True')  # True values for k-day ahead prediction
plt.plot(yhat_Conv1D, label='Predicted')    # Predicted values for k-day ahead
plt.title('Real vs. Predicted Stock Prices for k-Day Forecast using Conv1D')
plt.xlabel('Time (Days)')
plt.ylabel('Normalized Stock Price (Open Price)')
plt.legend()
plt.show()

# %%
# Plot the true and predicted stock prices for k-day forecast
plt.figure(figsize=(12, 6))
plt.plot(y_test_k_day_norm, label='True')  # True values for k-day ahead prediction
plt.plot(yhat_LSTM, label='Predicted')    # Predicted values for k-day ahead
plt.title('Real vs. Predicted Stock Prices for k-Day Forecast using LSTM')
plt.xlabel('Time (Days)')
plt.ylabel('Normalized Stock Price (Open Price)')
plt.legend()
plt.show()

# %%
# Plot the true and predicted stock prices for k-day forecast
plt.figure(figsize=(12, 6))
plt.plot(y_test_k_day_norm, label='True')  # True values for k-day ahead prediction
plt.plot(yhat_GRU, label='Predicted')    # Predicted values for k-day ahead
plt.title('Real vs. Predicted Stock Prices for k-Day Forecast using GRU')
plt.xlabel('Time (Days)')
plt.ylabel('Normalized Stock Price (Open Price)')
plt.legend()
plt.show()

# %%
import random
import matplotlib.pyplot as plt

# Dictionary of models
models = {
    "modelConv1D": model,
    "modelLSTM": modelLSTM,
    "modelGRU": modelGRU
}

# Randomly select a model for prediction
selected_model_name = random.choice(list(models.keys()))
selected_model = models[selected_model_name]
print(f"Using {selected_model_name} for prediction")

# Select a random index from the list of DataFrames
random_index = random.randint(0, len(df_list) - 1)
random_file = df_list[random_index]  # Get the DataFrame
file_name = keywords[random_index]  # Get the corresponding file name
file_name_prefix = file_name[:3]  # Extract the first 3 letters

# Print the file name prefix
# print(f"Randomly selected company file prefix: {file_name_prefix}")

# Make predictions with the selected model for the k-day forecast
yhat_k_day = selected_model.predict(X_test_k_day_norm)

# Select a random starting index for the 30-day subset
random_index = random.randint(0, len(y_test_k_day_norm) - 500)

# Plot the true and predicted stock prices for the selected company
plt.figure(figsize=(12, 6))
plt.plot(y_test_k_day_norm[random_index:random_index + 500], label='True')
plt.plot(yhat_k_day[random_index:random_index + 500], label='Predicted')
plt.title(f"Real vs. Predicted Stock Prices using {selected_model_name} (3-Day Forecast)")
plt.xlabel("Time Steps")
plt.ylabel("Normalized Stock Price (Open Price)")
plt.legend()
plt.show()
# Out:
# Using modelLSTM for prediction
